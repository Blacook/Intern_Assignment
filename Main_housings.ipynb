# %%
import BostonHousingAnalyzer 
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler, Normalizer
from IPython.core.display import display
import warnings
warnings.simplefilter('ignore')
warnings.filterwarnings('ignore')

# %%
housings = BostonHousingAnalyzer.Housings()
df_data = housings.get_data()
display("some rows of the data:", df_data)
display("some rows of the data:", housings.get_fundamental_statistics())
# Out:
# 'some rows of the data:'
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
df_Xtrain, df_Ytrain, df_Xtest, df_Ytest = housings.show_data_shape_summary()
# Out:
# the number of rows and columns:(506, 14)
# the number of any duplicate rows:0
# the number of NaN values:
#  CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64
# X_train shape: (379, 13)
# y_train shape: (379, 1)
# X_test  shape: (127, 13)
# Y_test  shape: (127, 1)

# %%
housings.choose_feature_data(corr_threshold=0.5)
# Out:
# ===== Comparison with the correlation coefficients =====
# 'correlation coefficients of feature variables with the target:'
#    features    corr_y
# 2     INDUS -0.527459
# 5        RM  0.698227
# 9       TAX -0.507594
# 10  PTRATIO -0.556732
# 12    LSTAT -0.755934
# 13     MEDV  1.000000

# %%
# choose scaler : StandardScaler, RobustScaler, MinMaxScaler, Normalizer
housings.princpal_components_analysis(n_components=2, scaler=Normalizer())
# Out:
# 'feature scaled data train'
#        CRIM        ZN     INDUS     CHAS       NOX        RM       AGE  \
# 0  0.000371  0.042607  0.011349  0.00000  0.000835  0.010855  0.135954
# 2  0.000223  0.085181  0.013650  0.00213  0.000952  0.015475  0.104347
# 3  0.011173  0.000000  0.023200  0.00000  0.000888  0.008294  0.126636
# 4  0.016072  0.000000  0.026851  0.00000  0.001007  0.010061  0.134698
# 5  0.000129  0.000000  0.033915  0.00000  0.000745  0.007315  0.120791
#
#         DIS       RAD       TAX   PTRATIO         B     LSTAT  MEDV
# 0  0.015406  0.013557  0.639101  0.036990  0.753616  0.035751  24.0
# 2  0.010194  0.008518  0.540900  0.037480  0.828918  0.012884  34.7
# 3  0.002212  0.030762  0.853641  0.025891  0.502418  0.021943  33.4
# 4  0.002699  0.035603  0.987985  0.029966  0.031998  0.038258  36.2
# 5  0.002284  0.004890  0.869258  0.024574  0.476943  0.022092  28.7
# train shape: (286, 14)
# 'feature scaled data test'
# ...

# %%
housings.AllSupervised(n_valid=5, scaled=False, PCA=False)
# Out:
# ============= Linear Regression =============
# test_scores(RMSE) for
# LinearRegression()
# mean of test_scores:5.48640632773734 std of test_scores:0.11551415440629871
# ======== Ridge(L2) Linear Regression ========
# test_scores(RMSE) for
# Ridge(alpha=0.3, max_iter=20, tol=10000.0)
# mean of test_scores:5.5150724559703885 std of test_scores:0.1187263211306184
# ======== Lasso(L1) Linear Regression ========
# test_scores(RMSE) for
# Lasso(alpha=0.3, max_iter=10000)
# mean of test_scores:5.74366699630289 std of test_scores:0.11339350673868766
# ==== Elastic Net(L1&L2) Linear Regression ====
# test_scores(RMSE) for
# ElasticNet(alpha=0.1, max_iter=10000, tol=0.001)
# mean of test_scores:5.69432662013345 std of test_scores:0.11470452185290793
# ========== k-neighbors Regression  ==========
# test_scores(RMSE) for
# KNeighborsRegressor(n_neighbors=10)
# mean of test_scores:7.210419018296943 std of test_scores:0.1795425669239447
# ========== Supprot Vector Regression  ==========
# ...

# %%
housings.HyperPrameterTuning(n_trials=10, n_valid=5, scaled=False, PCA=False)
# Out:
# [I 2022-06-15 10:55:26,344] A new study created in memory with name: no-name-59c8be97-1a17-4b61-8fa4-0ceaf4ab74ba
# ======== Ridge(L2) Linear Regression ========
# [I 2022-06-15 10:55:27,624] Trial 0 finished with value: -4.889157680860619 and parameters: {'regressor': 'Ridge', 'L2_alpha': 0.0017699722412548092, 'L2_max_iter': 59, 'L2_tol': 25.583542666293262}. Best is trial 0 with value: -4.889157680860619.
# ========= Decision Tree Regressor =========
# [I 2022-06-15 10:55:28,005] Trial 1 finished with value: -5.354581752306531 and parameters: {'regressor': 'Regression Tree', 'rt_max_depth': 11}. Best is trial 0 with value: -4.889157680860619.
# [I 2022-06-15 10:55:28,139] Trial 2 finished with value: -3.433078187532165 and parameters: {'regressor': 'LGBM', 'lgbm_learning_rate': 0.5207224083783977, 'lgbm_n_estimators': 119, 'lgbm_num_leaves': 3}. Best is trial 2 with value: -3.433078187532165.
# ...
